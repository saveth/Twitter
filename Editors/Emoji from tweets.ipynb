# %%
from pathlib import Path
import emoji

# %%
# open file with 1000 tweets
# run counting procedure
#display character set

# %%
# !pwd
# Out:
# /Users/wcz/Beanflows/All_Beans/Machine_Learning/Gradient_Ascent

# %%
d = collections.defaultdict(int)

folder_path = Path('data/tweets v1/')
# file_path = folder_path / 'tw314_318_1000.csv'
file_path = folder_path / 'tw314_318.csv'
max_len = 400*1000*1000
with open(str(file_path), 'r') as file:
    buf = ''
    count = 0
    for line in file:
        buf = file.readline(100000)
        count += len(buf)
        
        for c in buf:
            d[c] += 1
        
        if count > max_len:
            break;

print(len(d.keys()))
print(d.keys())
# Out:
# 17161
# dict_keys(['ⓡ', '▸', '耀', 'ץ', '\x16', '俸', '﹋', 'ظ', '滚', '崟', '\ue327', '偵', '🕗', '固', 'Ｆ', '\ue20c', '覽', '隶', '첫', '〖', '势', '®', 'ㅏ', '屌', '⊆', '壁', '찻', '授', '橄', '퉁', 'Ᵽ', '뱝', '壳', '죌', '茫', '▘', '♕', '﨑', '赦', '👝', '棺', '覇', 'Ꭲ', '葵', '츠', 'г', '겜', '븁', 'Ⴋ', '㉶', '棒', '吕', '双', '✑', '\\', '霜', '햑', '侄', 'ҽ', '专', '톡', '冻', '🕣', '⑀', '페', '貶', '▃', '㉡', '襟', '産', '࿖', '頂', 'v', '첩', '쩖', '🍐', '답', '𝂩', '医', 'ἷ', '⠁', '派', 'ู', '\ue023', '峙', '푴', '⇊', '🅄', '鉈', '🌔', 'ୱ', '⦇', '𝒉', '╱', '声', '১', '🎵', '😍', '蟑', '땋', 'Ụ', 'Ṃ', '칻', 'ã', '饭', 'α', '\ue512', '暮', '蜃', '舶', '🐹', '𝒶', '단', '湴', '맼', 'ฌ', 'ầ', '禮', '⍔', 'Ĕ', '뽄', '✓', '헉', '麥', 'ਠ', '\ue14c', '√', '躍', '̧', '땽', '쎅', 'ﮌ', 'ﮍ', '婚', '鈍', '聾', '┓', '宝', '潛', 'ὼ', '̝', '鲜', '刞', '酋', '!', '녜', '裂', 'Ắ', '攻', '韛', '徘', '󠄂', '안', '勾', '웜', '∋', '働', '攜', '歯', '韶', '껀', '◌', 'ፍ', 'う', 'ṧ', 'ܛ', '项', '자', '垂', 'ʓ', '凡', '🔺', '月', '届', 'ό', '藿', '殤', '닻', '작', '는', '⏩', '虚', '름', '澄', '력', '⠍', '겢', '🍂', '蒸', '봏', 'ᶅ', '琲', 'Ⓔ', '諾', '忙', '렛', '権', '༾', '煎', '림', '鯖', 'ᐞ', '玻', '௮', '약', '💣', 'ଖ', 'れ', '닌', '팰', 'ፊ', '箕', '풀', '陌', '읙', '존', '개', '🕜', '袮', '离', '둣', '娶', '뱆', '謄', '遥', 'ৃ', '꿍', '쎳', '淴', 'Đ', '剝', '従', '\U000fe19a', '牵', '₲', '挚', 'ڃ', '깃', '趕', '🐨', '🐡', 'ﭔ', 'ၚ', '땟', '藻', '褫', '맨', '𖣣', 'Ⓕ', '힄', '৹', '飘', '̓', '⠽', 'ﺒ', '\U0001f95a', '७', '﹪', '넫', '翆', '萩', '¢', '矜', '♾', '🔪', '४', '뺄', '⎹', 'Ƨ', '吳', '幌', '쑫', '긺', '↩', 'ꕥ', 'ᶠ', '芹', '∮', '億', '짲', '̄', 'ଝ', '\U000feb0f', '含', '뼝', '尊', 'ﭨ', '봠', '择', 'ℜ', '匠', '⑰', '⍣', '⏅', '伝', '萄', '읂', '扈', '菖', '剽', 'ŷ', '状', '推', '⓱', '쥡', '똫', '𒀫', '봤', '𝗩', '踝', '訏', '岾', 'Ằ', 'ര', 'ה', 'ٔ', '៏', '뷔', 'ᚒ', '춤', '깼', '©', '🕐', '忧', '望', '좋', '共', '卌', '懍', 'ය', '🐎', '霄', '範', '२', '〇', '엳', '괭', 'ि', '쳇', '性', '击', 'ℵ', '빊', '丢', 'ณ', '噸', '⃝', 'ඉ', '等', '貧', '힇', '⣿', '领', '后', '༼', '쑉', '尸', '쟇', 'ｚ', '⭐', '볋', '𝓞', '⫹', '\ue021', 'ᐁ', '⒘', '≅', '暇', '🕧', '꽹', '娃', '＋', '緊', '\ue502', '璧', '鮟', '蛍', 'Ꭷ', '͖', '薩', 'ﮰ', '菅', '赵', '쟐', 'फ', '᷇', '苔', '妙', 'ḩ', '⸊', '글', 'O', 'ಏ', '긎', '篆', '听', '잡', '⁴', '͋', '價', '㈉', '雰', '訥', '鴨', 'ᾰ', '륭', '髯', '蛙', '🐅', '𝑻', '멩', '諷', '}', 'ù', '묽', '邕', '뭣', 'ታ', 'ገ', '컼', '沈', '৫', '썽', '뵀', '敬', '矽', 'ほ', 'ポ', 'ﭭ', '델', '즏', '⫅', '向', 'อ', '봘', '悼', '몪', 'Ꮥ', '툴', '☆', '发', 'ﮪ', '蟇', 'ƚ', '〗', '✥', '♓', 'ഠ', '蹈', 'ռ', 'ఆ', '除', '输', '▌', '𝓘', '閹', '봉', '맍', '진', '톧', '⦚', '祓', '碩', '廼', 'ノ', '몉', '홙', '諧', 'Ӎ', 'উ', '絲', '℡', '갠', '↳', 'ණ', '廣', '猗', 'К', '땗', '藐', '귯', '챼', 'ੁ', '゚', '고', '寻', '늙', 'ሞ', 'ڋ', 'А', '본', '⓰', '◞', 'ۿ', '❌', '맛', '慣', '□', '鄂', '𝕆', '鄭', '볏', '兵', '憚', 'ǿ', '兼', '💰', '洸', '彷', 'দ', '↥', '🅔', 'ṣ', '⎟', '먕', '悴', 'ビ', '㉺', '临', 'и', '磯', '࿀', 'ট', '◊', '军', '边', 'ី', '亦', '૮', '𐂂', '➫', '💭', '开', '엱', '࿉', '다', '鎮', 'қ', 'చ', '♚', 'ి', '슈', '왠', '҉', '稱', '넌', '网', '📱', '끊', 'လ', '化', '泮', '암', '飢', '眈', 'ヨ', '🇹', '樸', '片', '賜', '✠', '试', '劇', '웹', '⿸', '倪', '찰', '💂', '♭', '⁝', 'ो', '핕', '貼', '참', '😎', '\u2067', '吻', '╣', '撩', '댘', '込', 'چ', '\u2004', '拏', '题', '돔', '໒', '𓍐', '士', '𝝅', '斜', '鎚', 'ﻯ', '😖', '꼳', 'ີ', '쩜', '鰹', '砂', '두', '⦔', '扑', '甲', 'ӥ', '𝔱', '헨', '✟', '촙', '츳', '🗳', '胚', '射', 'Ꮎ', '揭', '冪', '囧', '∂', '似', '냄', 'ሊ', '敞', 'ワ', 'ﻠ', 'ᐃ', '堆', '順', '諄', '핫', '흫', 'Í', '\uf821', 'Д', 'ũ', 'ﮱ', 'ৈ', '휩', '윘', 'ᗷ', 'ꔘ', '뺨', '𝒪', '\ue424', '\ue030', '합', 'ϲ', '‿', 'ḑ', '╧', '学', '으', 'ᅩ', '↚', '曙', '헫', '‹', '꒡', '梭', 'և', '竹', '筝', '複', 'ご', '酔', '̙', '急', '褒', 'ဲ', 'ု', '初', 'ᚐ', '旋', '빈', '¾', '📵', '酉', '↯', '孫', 'ꃍ', 'ਖ', '斃', '੭', '㬝', '龍', '神', '団', '냇', '鋸', '╞', 'ഒ', '㎆', 'ᕶ', '멐', '拉', '\U000fe33e', '圃', '賞', '됙', '총', '⒜', '胸', '熱', '┎', '攘', '🕳', '🏁', '늫', '🚬', '轰', 'Х', '쉐', '爹', '㏄', 'ॉ', '犯', '粉', 'ˡ', '🕵', '춬', 'ᙠ', '饅', '🆔', '瓏', '췈', '憫', '̡', '収', '尖', '🛄', '欐', '양', '번', 'ⷤ', 'ঘ', '∅', 'Ó', '𓅿', '𝕚', 'ℝ', '拠', '龐', '➭', '褪', '⌐', '팩', '\ue32d', '𝒂', '繽', '𝐞', '為', 'ଲ', '😄', 'ໝ', '📲', '茵', '血', '踉', '🏿', '貰', 'ᵅ', '🕞', '졌', '😊', 'ཾ', '扱', '慧', '镇', '쑴', '\U0001f925', 'ᴙ', '费', 'ꙭ', '숍', '⧔', 'ग', '⤴',  ...

# %%
def char_is_emoji(character):
    return character in emoji.UNICODE_EMOJI

# %%
e = sorted(d.keys())
f = ''.join(e)
# f
char_is_emoji(f[10000])

emojis = []

for c in f:
    if char_is_emoji(c):
        emojis.append(c)
        
emojis = ''.join(emojis)
print(len(emojis))
emojis
# Out:
# 1083
# '©®‼⁉™ℹ↔↕↖↗↘↙↩↪⌚⌛⌨⏏⏩⏪⏫⏬⏭⏮⏯⏰⏱⏲⏳⏸⏹⏺Ⓜ▪▫▶◀◻◼◽◾☀☁☂☃☄☎☑☔☕☘☝☠☢☣☦☪☮☯☸☹☺♀♂♈♉♊♋♌♍♎♏♐♑♒♓♠♣♥♦♨♻♿⚒⚓⚔⚕⚖⚗⚙⚛⚜⚠⚡⚪⚫⚰⚱⚽⚾⛄⛅�